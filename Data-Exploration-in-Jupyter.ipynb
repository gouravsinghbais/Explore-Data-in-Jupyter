# %% [markdown]
# # Load Dependencies and Dataset

# %%
# import dependencies
import pandas as pd

# %%
# load dataset
titanic_data = pd.read_csv('Titanic_dataset.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# # Get to Know Your Data

# %% [markdown]
# ## Preview Functions

# %%
# check first few rows of data
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# check last few rows of data
titanic_data.tail(7)
# Out:
#      PassengerId  Survived  Pclass  \
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                     Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                              Ware, Mr. Frederick    male   NaN      0
# 417                         Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
# check random sample of data 
titanic_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 75           967         0       1
# 133         1025         0       3
# 329         1221         0       2
# 12           904         1       1
# 233         1125         0       3
# 392         1284         0       3
# 74           966         1       1
# 78           970         0       2
# 59           951         1       1
# 408         1300         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 75                              Keeping, Mr. Edwin    male  32.5      0
# 133                          Thomas, Mr. Charles P    male   NaN      1
# 329                            Enander, Mr. Ingvar    male  21.0      0
# 12   Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 233                           Linehan, Mr. Michael    male   NaN      0
# 392                  Abbott, Master. Eugene Joseph    male  13.0      0
# 74                            Geiger, Miss. Amalie  female  35.0      0
# 78                  Aldworth, Mr. Charles Augustus    male  30.0      0
# 59                     Chaudanson, Miss. Victorine  female  36.0      0
# 408                Riordan, Miss. Johanna Hannah""  female   NaN      0
#
#      Parch     Ticket      Fare Cabin Embarked
# 75       0     113503  211.5000  C132        C
# 133      0       2621    6.4375   NaN        C
# 329      0     236854   13.0000   NaN        S
# 12       0      21228   82.2667   B45        S
# 233      0     330971    7.8792   NaN        Q
# 392      2  C.A. 2673   20.2500   NaN        S
# 74       0     113503  211.5000  C130        C
# 78       0     248744   13.0000   NaN        S
# 59       0   PC 17608  262.3750   B61        C
# 408      0     334915    7.7208   NaN        Q

# %% [markdown]
# ## Gather Basic Information from Data

# %%
# check datatypes, null values and memory usage
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# check dataframe columns
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# check dataframe dtypes 
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# check shape and size of data 
titanic_data.shape, titanic_data.size
# Out:
# ((418, 12), 5016)

# %% [markdown]
# ## Descriptive Stetistics

# %%
# check descriptive statistics of data
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # Filtering and Subsetting Data

# %%
# check columna and its data type 
titanic_data['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
# check columna and its data type 
titanic_data['Age'][:5]
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %% [markdown]
# ## loc Function

# %%
# check values with index value
titanic_data_index = titanic_data.set_index('Name')
titanic_data_index.loc['Wilkes, Mrs. James (Ellen Needs)']
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                      893         1       3
# Myles, Mr. Thomas Francis                             894         0       2
# Wirz, Mr. Albert                                      895         0       3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896         1       3
# Svensson, Mr. Johan Cervin                            897         0       3
# ...                                                   ...       ...     ...
# Henriksson, Miss. Jenny Lovisa                       1304         1       3
# Spector, Mr. Woolf                                   1305         0       3
# Oliva y Ocana, Dona. Fermina                         1306         1       1
# Saether, Mr. Simon Sivertsen                         1307         0       3
# Ware, Mr. Frederick                                  1308         0       3
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Wilkes, Mrs. James (Ellen Needs)              female  47.0      1      0
# Myles, Mr. Thomas Francis                       male  62.0      0      0
# Wirz, Mr. Albert                                male  27.0      0      0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# Svensson, Mr. Johan Cervin                      male  14.0      0      0
# ...                                              ...   ...    ...    ...
# Henriksson, Miss. Jenny Lovisa                female  28.0      0      0
# Spector, Mr. Woolf                              male   NaN      0      0
# Oliva y Ocana, Dona. Fermina                  female  39.0      0      0
# Saether, Mr. Simon Sivertsen                    male  38.5      0      0
# Ware, Mr. Frederick                             male   NaN      0      0
#
#                                                           Ticket      Fare  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                          363272    7.0000
# Myles, Mr. Thomas Francis                                 240276    9.6875
# Wirz, Mr. Albert                                          315154    8.6625
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)             3101298   12.2875
# Svensson, Mr. Johan Cervin                                  7538    9.2250
# ...                                                          ...       ...
# Henriksson, Miss. Jenny Lovisa                            347086    7.7750
# Spector, Mr. Woolf                                     A.5. 3236    8.0500
# Oliva y Ocana, Dona. Fermina                            PC 17758  108.9000
# Saether, Mr. Simon Sivertsen                  SOTON/O.Q. 3101262    7.2500
# Ware, Mr. Frederick                                       359309    8.0500
#
#                                              Cabin Embarked
# Name
# Wilkes, Mrs. James (Ellen Needs)               NaN        S
# Myles, Mr. Thomas Francis                      NaN        Q
# Wirz, Mr. Albert                               NaN        S
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)   NaN        S
# Svensson, Mr. Johan Cervin                     NaN        S
# ...                                            ...      ...
# Henriksson, Miss. Jenny Lovisa                 NaN        S
# Spector, Mr. Woolf                             NaN        S
# Oliva y Ocana, Dona. Fermina                  C105        C
# Saether, Mr. Simon Sivertsen                   NaN        S
# Ware, Mr. Frederick                            NaN        S
#
# [416 rows x 11 columns]

# %%
# check values with index value
titanic_data_index = titanic_data.set_index('Name')
titanic_data_index.loc['Wilkes, Mrs. James (Ellen Needs)':'Ware, Mr. Frederick', ['Survived', 'Age']]
# Out:
#                                               Survived   Age
# Name
# Wilkes, Mrs. James (Ellen Needs)                     1  47.0
# Myles, Mr. Thomas Francis                            0  62.0
# Wirz, Mr. Albert                                     0  27.0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1  22.0
# Svensson, Mr. Johan Cervin                           0  14.0
# ...                                                ...   ...
# Henriksson, Miss. Jenny Lovisa                       1  28.0
# Spector, Mr. Woolf                                   0   NaN
# Oliva y Ocana, Dona. Fermina                         1  39.0
# Saether, Mr. Simon Sivertsen                         0  38.5
# Ware, Mr. Frederick                                  0   NaN
#
# [416 rows x 2 columns]

# %% [markdown]
# ## iloc function

# %%
# check values with index number
titanic_data_index = titanic_data.set_index('Name')
titanic_data_index.iloc[1]
# Out:
# PassengerId       893
# Survived            1
# Pclass              3
# Sex            female
# Age              47.0
# SibSp               1
# Parch               0
# Ticket         363272
# Fare              7.0
# Cabin             NaN
# Embarked            S
# Name: Wilkes, Mrs. James (Ellen Needs), dtype: object

# %%
# check values with index number
titanic_data_index = titanic_data.set_index('Name')
titanic_data_index.iloc[1:5, 1:5]
# Out:
#                                               Survived  Pclass     Sex   Age
# Name
# Wilkes, Mrs. James (Ellen Needs)                     1       3  female  47.0
# Myles, Mr. Thomas Francis                            0       2    male  62.0
# Wirz, Mr. Albert                                     0       3    male  27.0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1       3  female  22.0

# %%
# access data with iloc
titanic_data.iloc[0:5, 0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex
# 0                              Kelly, Mr. James    male
# 1              Wilkes, Mrs. James (Ellen Needs)  female
# 2                     Myles, Mr. Thomas Francis    male
# 3                              Wirz, Mr. Albert    male
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female

# %% [markdown]
# ## Conditional filtering

# %%
# filter data based on conditions
titanic_data[titanic_data['Pclass'] == 3]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 412                Henriksson, Miss. Jenny Lovisa  female  28.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket     Fare Cabin Embarked
# 0                330911   7.8292   NaN        Q
# 1                363272   7.0000   NaN        S
# 3                315154   8.6625   NaN        S
# 4               3101298  12.2875   NaN        S
# 5                  7538   9.2250   NaN        S
# ..                  ...      ...   ...      ...
# 412              347086   7.7750   NaN        S
# 413           A.5. 3236   8.0500   NaN        S
# 415  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416              359309   8.0500   NaN        S
# 417                2668  22.3583   NaN        C
#
# [218 rows x 12 columns]

# %%
# filter data based on multiple conditions 
titanic_data[(titanic_data['Pclass'] == 3) & (titanic_data['Age'] >= 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 6            898         1       3
# 19           911         1       3
# 25           917         0       3
# 32           924         1       3
# 40           932         0       3
# 42           934         0       3
# 49           941         1       3
# 56           948         0       3
# 99           991         0       3
# 130         1022         0       3
# 134         1026         0       3
# 139         1031         0       3
# 145         1037         0       3
# 152         1044         0       3
# 153         1045         1       3
# 174         1066         0       3
# 195         1087         0       3
# 206         1098         1       3
# 210         1102         0       3
# 214         1106         1       3
# 228         1120         0       3
# 254         1146         0       3
# 260         1152         0       3
# 285         1177         0       3
# 291         1183         1       3
# 294         1186         0       3
# 300         1192         0       3
# 309         1201         1       3
# 313         1205         1       3
# 337         1229         0       3
# 341         1233         0       3
# 347         1239         1       3
# 359         1251         1       3
# 399         1291         0       3
# 415         1307         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                     Kelly, Mr. James    male  34.5      0
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 6                                 Connolly, Miss. Kate  female  30.0      0
# 19               Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 25                             Robins, Mr. Alexander A    male  50.0      1
# 32            Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0      1
# 40                                    Karun, Mr. Franz    male  39.0      0
# 42                               Goldsmith, Mr. Nathan    male  41.0      0
# 49      Coutts, Mrs. William (Winnie Minnie" Treanor)"  female  36.0      0
# 56                                     Cor, Mr. Bartol    male  35.0      0
# 99                        Nancarrow, Mr. William Henry    male  33.0      0
# 130                            Spinner, Mr. Henry John    male  32.0      0
# 134                             Dintcheff, Mr. Valtcho    male  43.0      0
# 139                     Goodwin, Mr. Charles Frederick    male  40.0      1
# 145                          Vander Planke, Mr. Julius    male  31.0      3
# 152                                 Storey, Mr. Thomas    male  60.5      0
# 153     Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)  female  36.0      0
# 174         Asplund, Mr. Carl Oscar Vilhelm Gustafsson    male  40.0      1
# 195                  Karlsson, Mr. Julius Konrad Eugen    male  33.0      0
# 206                           McGowan, Miss. Katherine  female  35.0      0
# 210                        Andersen, Mr. Albert Karvin    male  32.0      0
# 214             Andersson, Miss. Ida Augusta Margareta  female  38.0      4
# 228                          Everett, Mr. Thomas James    male  40.5      0
# 254                                Wenzel, Mr. Linhart    male  32.5      0
# 260               de Messemaeker, Mr. Guillaume Joseph    male  36.5      1
# 285                                Dennis, Mr. William    male  36.0      0
# 291             Daly, Miss. Margaret Marcella Maggie""  female  30.0      0
# 294                          Wittevrongel, Mr. Camille    male  36.0      0
# 300                          Olsson, Mr. Oscar Wilhelm    male  32.0      0
# 309         Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1
# 313                                Carr, Miss. Jeannie  female  37.0      0
# 337                                  Elias, Mr. Joseph    male  39.0      0
# 341                         Lundstrom, Mr. Thure Edvin    male  32.0      0
# 347    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0      0
# 359  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...  female  30.0      1
# 399                           Conlon, Mr. Thomas Henry    male  31.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
#
#      Parch              Ticket     Fare Cabin Embarked
# 0        0              330911   7.8292   NaN        Q
# 1        0              363272   7.0000   NaN        S
# 6        0              330972   7.6292   NaN        Q
# 19       0                2696   7.2250   NaN        C
# 25       0           A/5. 3337  14.5000   NaN        S
# 32       2           C.A. 2315  20.5750   NaN        S
# 40       1              349256  13.4167   NaN        C
# 42       0  SOTON/O.Q. 3101263   7.8500   NaN        S
# 49       2          C.A. 37671  15.9000   NaN        S
# 56       0              349230   7.8958   NaN        S
# 99       0          A./5. 3338   8.0500   NaN        S
# 130      0     STON/OQ. 369943   8.0500   NaN        S
# 134      0              349226   7.8958   NaN        S
# 139      6             CA 2144  46.9000   NaN        S
# 145      0              345763  18.0000   NaN        S
# 152      0                3701      NaN   NaN        S
# 153      2              350405  12.1833   NaN        S
# 174      5              347077  31.3875   NaN        S
# 195      0              347465   7.8542   NaN        S
# 206      0                9232   7.7500   NaN        Q
# 210      0              C 4001  22.5250   NaN        S
# 214      2              347091   7.7750   NaN        S
# 228      0           C.A. 6212  15.1000   NaN        S
# 254      0              345775   9.5000   NaN        S
# 260      0              345572  17.4000   NaN        S
# 285      0           A/5 21175   7.2500   NaN        S
# 291      0              382650   6.9500   NaN        Q
# 294      0              345771   9.5000   NaN        S
# 300      0              347079   7.7750   NaN        S
# 309      0              350026  14.1083   NaN        S
# 313      0              368364   7.7500   NaN        Q
# 337      2                2675   7.2292   NaN        C
# 341      0              350403   7.5792   NaN        S
# 347      0                2688   7.2292   NaN        C
# 359      0              349910  15.5500   NaN        S
# 399      0               21332   7.7333   NaN        Q
# 415      0  SOTON/O.Q. 3101262   7.2500   NaN        S

# %%
titanic_data[titanic_data['Age'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                     Saether, Mr. Simon Sivertsen    male  38.5      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0              330911    7.8292   NaN        Q
# 1        0              363272    7.0000   NaN        S
# 2        0              240276    9.6875   NaN        Q
# 3        0              315154    8.6625   NaN        S
# 4        1             3101298   12.2875   NaN        S
# ..     ...                 ...       ...   ...      ...
# 409      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
# [332 rows x 12 columns]

# %%
titanic_data[titanic_data['Name'].str.startswith('K')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 16           908         0       2
# 35           927         0       3
# 40           932         0       3
# 44           936         1       1
# 75           967         0       1
# 85           977         0       3
# 121         1013         0       3
# 124         1016         0       3
# 153         1045         1       3
# 165         1057         1       3
# 195         1087         0       3
# 223         1115         0       3
# 245         1137         0       1
# 246         1138         1       2
# 249         1141         1       3
# 263         1155         1       3
# 321         1213         0       3
# 324         1216         1       1
# 376         1268         1       3
# 394         1286         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 16                                  Keane, Mr. Daniel    male  35.0      0
# 35   Katavelas, Mr. Vassilios (Catavelas Vassilios")"    male  18.5      0
# 40                                   Karun, Mr. Franz    male  39.0      0
# 44   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)  female  45.0      1
# 75                                 Keeping, Mr. Edwin    male  32.5      0
# 85                                 Khalil, Mr. Betros    male   NaN      1
# 121                                 Kiernan, Mr. John    male   NaN      1
# 124                                 Kennedy, Mr. John    male   NaN      0
# 153    Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)  female  36.0      0
# 165        Kink-Heilmann, Mrs. Anton (Luise Heilmann)  female  26.0      1
# 195                 Karlsson, Mr. Julius Konrad Eugen    male  33.0      0
# 223                     Karlsson, Mr. Einar Gervasius    male  21.0      0
# 245                           Kenyon, Mr. Frederick R    male  41.0      1
# 246             Karnes, Mrs. J Frank (Claire Bennett)  female  22.0      0
# 249         Khalil, Mrs. Betros (Zahie Maria" Elias)"  female   NaN      1
# 263                      Klasen, Miss. Gertrud Emilia  female   1.0      1
# 321                             Krekorian, Mr. Neshan    male  25.0      0
# 324                            Kreuchen, Miss. Emilie  female  39.0      0
# 376                                 Kink, Miss. Maria  female  22.0      2
# 394                          Kink-Heilmann, Mr. Anton    male  29.0      3
#
#      Parch        Ticket      Fare  Cabin Embarked
# 0        0        330911    7.8292    NaN        Q
# 16       0        233734   12.3500    NaN        Q
# 35       0          2682    7.2292    NaN        C
# 40       1        349256   13.4167    NaN        C
# 44       0         11753   52.5542    D19        S
# 75       0        113503  211.5000   C132        C
# 85       0          2660   14.4542    NaN        C
# 121      0        367227    7.7500    NaN        Q
# 124      0        368783    7.7500    NaN        Q
# 153      2        350405   12.1833    NaN        S
# 165      1        315153   22.0250    NaN        S
# 195      0        347465    7.8542    NaN        S
# 223      0        350053    7.7958    NaN        S
# 245      0         17464   51.8625    D21        S
# 246      0  F.C.C. 13534   21.0000    NaN        S
# 249      0          2660   14.4542    NaN        C
# 263      1        350405   12.1833    NaN        S
# 321      0          2654    7.2292  F E57        C
# 324      0         24160  211.3375    NaN        S
# 376      0        315152    8.6625    NaN        S
# 394      1        315153   22.0250    NaN        S

# %%
# fetch data with query method
titanic_data.query('Age>=30')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 6            898         1       3
# 11           903         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 6                               Connolly, Miss. Kate  female  30.0      0
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# ..                                               ...     ...   ...    ...
# 404                     Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 407                       Widener, Mr. George Dunton    male  50.0      1
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                     Saether, Mr. Simon Sivertsen    male  38.5      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0              330911    7.8292   NaN        Q
# 1        0              363272    7.0000   NaN        S
# 2        0              240276    9.6875   NaN        Q
# 6        0              330972    7.6292   NaN        Q
# 11       0                 694   26.0000   NaN        S
# ..     ...                 ...       ...   ...      ...
# 404      0               17765   27.7208   D40        C
# 407      1              113503  211.5000   C80        C
# 411      0               19928   90.0000   C78        Q
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
# [147 rows x 12 columns]

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# ## Value Counts

# %%
# check the frequency of values in Sex column
titanic_data['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
# check the frequency of values in passanger class 
titanic_data['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
# multi index value counts
titanic_data[['Pclass', 'Age']].value_counts()
# Out:
# Pclass  Age
# 3       21.0    11
#         22.0    10
#         24.0     9
#         18.0     8
#         27.0     7
#                 ..
# 2       45.0     1
#         44.0     1
#         43.0     1
#         38.0     1
# 3       60.5     1
# Length: 141, dtype: int64

# %% [markdown]
# ## Grouping and Aggregation

# %%
## Group data by sex in titanic dataset
titanic_data.groupby(['Sex']).mean()
# Out:
# /var/folders/0k/ftvl7p0j58v4p29wsgrkgnvr0000gn/T/ipykernel_39691/1589131673.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic_data.groupby(['Sex']).mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female  1096.789474       1.0  2.144737  30.272362  0.565789  0.598684
# male    1102.620301       0.0  2.334586  30.272732  0.379699  0.274436
#
#              Fare
# Sex
# female  49.747699
# male    27.527877

# %%
## Group data by sex in titanic dataset
titanic_data.groupby(['Sex', 'Pclass']).mean()
# Out:
# /var/folders/0k/ftvl7p0j58v4p29wsgrkgnvr0000gn/T/ipykernel_39691/1692779632.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic_data.groupby(['Sex', 'Pclass']).mean()
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1       1104.080000       1.0  41.333333  0.560000  0.500000
#        2       1111.200000       1.0  24.376552  0.533333  0.766667
#        3       1085.722222       1.0  23.073400  0.583333  0.597222
# male   1       1093.087719       0.0  40.520000  0.403509  0.280702
#        2       1121.142857       0.0  30.940678  0.301587  0.142857
#        3       1098.349315       0.0  24.525104  0.404110  0.328767
#
#                      Fare
# Sex    Pclass
# female 1       115.591168
#        2        26.438750
#        3        13.735129
# male   1        75.586551
#        2        20.184654
#        3        11.826350

# %%
# plot the distribution
titanic_data.groupby(['Sex']).mean().plot(kind='bar')
# Out:
# /var/folders/0k/ftvl7p0j58v4p29wsgrkgnvr0000gn/T/ipykernel_39691/33066929.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic_data.groupby(['Sex']).mean().plot(kind='bar')
# <Axes: xlabel='Sex'>

# %%
# unstack the groups for inner distribution
titanic_data.groupby(['Pclass', 'Survived'] )['Survived'].count().unstack('Pclass')
# Out:
# Pclass     1   2    3
# Survived
# 0         57  63  146
# 1         50  30   72

# %%
# conditional groupby 
titanic_data.loc[titanic_data['Age']>25, ['Pclass', 'Survived']].groupby(['Pclass', 'Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0           42
#         1           40
# 2       0           37
#         1           12
# 3       0           40
#         1           19
# Name: Survived, dtype: int64

# %% [markdown]
# ## Aggregation Function

# %%
# aggreagate data with aggregate function 
titanic_data.aggregate(['count', 'mean'])
# Out:
# /var/folders/0k/ftvl7p0j58v4p29wsgrkgnvr0000gn/T/ipykernel_39691/2120785002.py:2: FutureWarning: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   titanic_data.aggregate(['count', 'mean'])
#        PassengerId    Survived     Pclass   Name    Sex        Age  \
# count        418.0  418.000000  418.00000  418.0  418.0  332.00000
# mean        1100.5    0.363636    2.26555    NaN    NaN   30.27259
#
#             SibSp       Parch  Ticket        Fare  Cabin  Embarked
# count  418.000000  418.000000   418.0  417.000000   91.0     418.0
# mean     0.447368    0.392344     NaN   35.627188    NaN       NaN

# %%
# apply aggregate function with groupby
titanic_data.groupby(['Pclass', 'Survived'] )['Survived'].agg(["count", "mean"])
# Out:
#                  count  mean
# Pclass Survived
# 1      0            57   0.0
#        1            50   1.0
# 2      0            63   0.0
#        1            30   1.0
# 3      0           146   0.0
#        1            72   1.0

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# ## Checking and Handling Missing Values

# %% [markdown]
# ## Dropna

# %%
# drop NaN values
titanic_data_dropna = titanic_data.dropna(axis=1)
titanic_data_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Embarked     418 non-null    object
# dtypes: int64(5), object(4)
# memory usage: 29.5+ KB

# %% [markdown]
# ## Fillna

# %%
# replace NaN values
titanic_data_fillna = titanic_data.copy()
titanic_data_fillna['Age'].fillna(value=titanic_data_fillna['Age'].mean(),inplace=True)
titanic_data_fillna.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#           Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413  30.27259      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.00000      0      0            PC 17758  108.9000  C105        C
# 415  38.50000      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416  30.27259      0      0              359309    8.0500   NaN        S
# 417  30.27259      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ## Joining DIfferent Datasets

# %%
# join datasets
duplicate_data = pd.concat([titanic_data, titanic_data], axis=0)
duplicate_data.shape
# Out:
# (836, 12)

# %%
# merge two datasets
df_1 = pd.DataFrame({
     "column_a": ["A", "B", "C", "D", "E"],
     "column_b": [10, 11, 12, 13, 14]},
     index=["1", "2", "3", "4", "5"]
)

df_2 = pd.DataFrame({
     "column_a": ["A", "B", "E"],
     "column_c": [100, 101, 104]},
     index=["1", "2", "3"]
)

pd.merge(df_1, df_2, on='column_a', how='inner')
# Out:
#   column_a  column_b  column_c
# 0        A        10       100
# 1        B        11       101
# 2        E        14       104

# %% [markdown]
# ## Handling duplicate values

# %%
# drop duplicated from data
duplicate_data.drop_duplicates(inplace=True, ignore_index=True)
duplicate_data.shape
# Out:
# (418, 12)

# %% [markdown]
# ## Convert Data Types of columns

# %%
# convert colum data types
titanic_data_fillna['Age'] = titanic_data_fillna['Age'].astype(int)
titanic_data_fillna.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex  Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male   34      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                     Myles, Mr. Thomas Francis    male   62      0      0
# 3                              Wirz, Mr. Albert    male   27      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Pivot Tables and Cross-Tabulation

# %%
# pivot table
import numpy as np
pd.pivot_table(titanic_data, index = ["Sex","Age"], aggfunc=np.sum)
# Out:
# /var/folders/0k/ftvl7p0j58v4p29wsgrkgnvr0000gn/T/ipykernel_39691/3409654350.py:3: FutureWarning: The operation <function sum at 0x109b1d3a0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pd.pivot_table(titanic_data, index = ["Sex","Age"], aggfunc=np.sum)
#                   Fare  Parch  PassengerId  Pclass  SibSp  Survived
# Sex    Age
# female 0.17    20.5750      2         1246       3      1         1
#        0.92    27.7500      2         1142       2      1         1
#        1.00    70.4625      4         3352       8      3         3
#        2.00    20.2125      1         1176       3      1         1
#        3.00    13.7750      1         1301       3      1         1
# ...                ...    ...          ...     ...    ...       ...
# male   61.00  274.7250      3         2119       3      1         0
#        62.00    9.6875      0          894       2      0         0
#        63.00   26.0000      0          905       2      1         0
#        64.00   75.2500      0         1128       1      1         0
#        67.00  221.7792      0          973       1      1         0
#
# [115 rows x 6 columns]

# %%
# pandas crosstab 
pd.crosstab(titanic_data['Sex'],  titanic_data['Survived'])
# Out:
# Survived    0    1
# Sex
# female      0  152
# male      266    0
